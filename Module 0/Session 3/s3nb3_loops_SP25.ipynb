# %% [markdown]
# <a href="https://colab.research.google.com/github/btaitel/flaming-octo-nemesis/blob/master/Module%200/Session%203/s3nb3_loops_SP25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loops

# %% [markdown]
# ## Python Loop Types
#
# #### `for` loops
#
# #### `while` loops

# %% [markdown]
# ### `for` loops
#
# `for` loops are for iterating over a collection (like a list or tuple) or an iterater. The standard syntax for a for loop is:
#
# **********************
#
# `for` value in collection:
#
#     # do something with value

# %%
# Simple example
# Iterating over a list
print("List Iteration")

l = ["msa", "cse", "6040"]
for i in l:
    print(i)
# Out:
# List Iteration
# msa
# cse
# 6040

# %% [markdown]
# #### You can advance a `for` loop to the next iteration, skipping the remainder of the block, using the `continue` keyword.
#
# See the below example, which sums up integers in a list and skips None values:

# %%
lst_example = [1, 2, None, 4, None, 5]
total = 0

for value in lst_example:
    if value is None:
        continue #go to the next step of the for loop
    total += value

display(total)

#this is using the continue keyword in order to avoid errors, such as:
#when there are none values in the lists and we cant add a None value to an integer

# %% [markdown]
# #### A `for` loop can be exited altogether with the `break` keyword.
#
# This code sums elements of the list until a 5 is reached:

# %%
lst_example_2 = [1, 2, 0, 4, 6, 5, 2, 1]
total_up_to_5 = 0

for value in lst_example_2:
    if value == 5:
        break
    total_up_to_5 += value

display(total_up_to_5)

# %% [markdown]
# #### Note that the `break` keyword only terminates the innermost loop, if the loop running is an interior loop in a series of nested loops.
#
# #### Outer for loops in the nested loop structure will continue to run. We will show an example of this in the next notebook, with ranges.

# %% [markdown]
# ## `while` loops
#
# #### A `while` loop specifies a condition and a block of code that is to be executed until the condition evaluates to `False` or the loop is explicitly ended with `break.`
#
# #### When the condition becomes false, the line immediately after the loop in the program is executed.
#
# The standard syntax for a `while` loop is as follows:
#
# *************************************
#
# `while` (expression to evaluate):
#
#     statement(s) that do/does something

# %%
# Simple example

count = 0

while (count < 3):
    count = count + 1
    print(count)
#notice here that we are printing 3 because we are doing the evaluation first,
#and then we are adding the number, so we say hey 2 is less than 3, run it. and 1, and print that 2+1

print("the end")
# Out:
# 1
# 2
# 3
# the end

# %%
# flipping the print and the increment. now we are print 0 1 2

count = 0

while (count < 3):
    print(count)
    count = count + 1

print("the end")
# Out:
# 0
# 1
# 2
# the end

# %%
# Simple example with break
# Walk through the logic
x = 256
total = 0

while x > 0:
    if total > 500:
        break
    total += x
    print(total)

#itll make the total 256, print that, then
#x doesnt change (its always > 0) so it basically will keep running until total > 500
#so the second iteration, it will make total 512, print that.
#then go back for another iteration, and then break
#then itll print the text, and 512 again
print("out of the while loop")
print(total)

#so this example actually does change the variable we are using to evaluate the while loop
# Out:
# 256
# 512
# out of the while loop
# 512

# %% [markdown]
# ### A `while` loop can be used with an `else` statement.
#
# #### The `else` clause is only executed when your `while` condition becomes `False`. If you break out of the loop, or if an exception is raised, it won’t be executed.
#
# #### Why would you want to use a `while..else` conditional structure?
#
# This allows you to control what happens when the `while` condition fails, directly in the `while` loop itself. This is very good for readability and control in your code, because you can see, **right there in the loop** what happens when the condition fails.
#
# So this is actually a **very good way** of executing your `while` loops.

# %% [markdown]
# This is the syntax:
#
# ********************************
#
# while condition:
#
#      # execute these statements
#
# else:
#
#      # execute these statements

# %%
# simple example
# walk through the logic after running the cell
count = 0

while (count < 3):
    count = count + 1
    print(count)
else:
    print("In else block")
    print(count)

# %%
items = ["apple","banana","orange"]

target = "mango"

i = 0

while i < len(items):
  if items[i] == target:
    print("found the mango")
    break
  i+=1
else:
  print("Mango not in list")

#so pretty much its using i as the incrememtor that will stop the while loop
#and as the index that helps us check through the list

# i is doing two jobs:
# Tracking position in the list (index)
# Controlling loop progress (counter)


#this while else loop, the goal is to search for a target item
# Out:
# Mango not in list

# %% [markdown]
# ### What are your questions on `for` and `while` loops?
